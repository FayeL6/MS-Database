# %%
# import msp2db as msp
# import sqlite3 as sql
import pandas as pd
# from io import StringIO
# import json

# %%
d = pd.read_table("data/acedox_raw_20210311.msp")

# %%
d.head(50)
# Out:
#                               RT1-A: 53.2323701089421
# 0                            RT2-A: 0.557827113148572
# 1                                        Name: Blob 1
# 2                                 Suspected_matches:
# 3                                           Formula:
# 4                                                MW:
# 5                                         ExactMass:
# 6                                              CAS#:
# 7                         Derivatization_Agent: MSTFA
# 8   Comments:  UID="" Contributor_ID="LDY" Confirm...
# 9                    Retention_index:  SemiStdNP=2092
# 10                                    Num Peaks:  198
# 11                   29 5; 39 11; 40 1; 41 50; 42 3;
# 12                  43 29; 44 9; 45 80; 46 4; 47 29;
# 13                    48 1; 51 3; 52 1; 53 15; 54 2;
# 14                   55 61; 56 3; 57 6; 58 7; 59 19;
# 15                   60 4; 61 18; 62 1; 63 1; 65 10;
# 16                   66 2; 67 27; 68 3; 69 48; 70 4;
# ...
